# %%
import cfdnetplus
import os
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
mainfolder='airfoil2d/airFoil_450_ssim_rmsprop/'
modelfolder='cfdnetplus_models/model_ssim_rmsprop/'

fields= ['U','p','k','omega', 'nut']
xlim =[-50,50]
ylim = [-30 , 30]
xres=256
yres=66
zcut=0.05

# %%
folder='airfoil2d/airFoil_450_org/'
cfdnetplus.extractInput2d(folder,fields, xlim, ylim,xres,yres,zcut)
label=np.load(folder+'/input.npy')
# Out:
# airfoil2d/airFoil_450_org/
# airFoil_450_org_0
# airFoil_450_org_100
# airFoil_450_org_150
# airFoil_450_org_200
# airFoil_450_org_250
# airFoil_450_org_300
# airFoil_450_org_336
# airFoil_450_org_50
# write airfoil2d/airFoil_450_org//input.npy

# %%
cfdnetplus.extractInput2d(mainfolder,fields, xlim, ylim,xres,yres,zcut)
# Out:
# airfoil2d/airFoil_450_ssim_rmsprop/
# airFoil_450_mse_0
# airFoil_450_ssim_rmsprop_0
# airFoil_450_ssim_rmsprop_2
# airFoil_450_ssim_rmsprop_20
# write airfoil2d/airFoil_450_ssim_rmsprop//input.npy

# %%
data=np.load(mainfolder+'/input.npy')

# %%
model = tf.keras.models.load_model(modelfolder,compile=False)
normal=np.load(modelfolder+'/normal.npy')

# %%
data=data*1/normal

# %%
prediction=model.predict(data)
prediction=prediction*normal
np.save(mainfolder+'/pred',prediction)
data=data*normal
# Out:
# 1/1 [==============================] - 0s 109ms/step

# %%
pred=np.load(mainfolder+'/pred.npy')
n=0
fig = plt.figure(figsize=(10, 14))
[a,b,c,d]=data.shape
titles= ['U_x','U_y','U_z','p','k','omega', 'nut']
col=3
for i in range(d):
    fig.add_subplot(d, col, (i*3)+1)
    plt.imshow(data[n,:,:,i],extent=[xlim[0],xlim[1],ylim[0],ylim[1]])
    plt.title(str((i*1)+1) + ' input ' +titles[i])
    plt.axis('off')
    plt.colorbar()
    
    fig.add_subplot(d, col, (i*3)+2)
    plt.imshow(pred[n,:,:,i],extent=[xlim[0],xlim[1],ylim[0],ylim[1]])
    plt.title(str((i*2)+2)+' pred '+titles[i])
    plt.axis('off')
    plt.colorbar()
    
    fig.add_subplot(d, col, (i*3)+3)
    plt.imshow(label[n,:,:,i],extent=[xlim[0],xlim[1],ylim[0],ylim[1]])
    plt.title(str((i*2)+3)+' label '+titles[i])
    plt.axis('off')
    plt.colorbar()
    
  

plt.show()

# %%
cfdnetplus.pred2OF2D(mainfolder,fields,xlim,ylim)
# Out:
# airFoil_450_mse_0
# airFoil_450_ssim_rmsprop_0
# airFoil_450_ssim_rmsprop_2
# airFoil_450_ssim_rmsprop_20
# folder airfoil2d/airFoil_450_ssim_rmsprop//21 was created
# write airfoil2d/airFoil_450_ssim_rmsprop//21/U
# write airfoil2d/airFoil_450_ssim_rmsprop//21/p
# write airfoil2d/airFoil_450_ssim_rmsprop//21/k
# write airfoil2d/airFoil_450_ssim_rmsprop//21/omega
# write airfoil2d/airFoil_450_ssim_rmsprop//21/nut
