# %%
import cfdnetplus
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
fields= ['U','p','k','omega', 'nut']
mainfolder='airfoil2d/airFoil_500'

xlim =[-50,50]
ylim = [-40 , 40]
xres=256
yres=66
zcut=0.05

# %%
cfdnetplus.extractInput2d(mainfolder,fields, xlim, ylim,xres,yres,zcut)
# Out:
# airfoil2d/airFoil_500
# airFoil_500_0
# airFoil_500_20
# write airfoil2d/airFoil_500/input.npy

# %%
data=np.load(mainfolder+'/input.npy')

# %%
cfdnetplus.pred(mainfolder,data,'foil3')
# Out:
# 1/1 [==============================] - 0s 144ms/step
# succesful prediction stored at airfoil2d/airFoil_500/pred.npy

# %%
pred=np.load(mainfolder+'/pred.npy')
n=0
fig = plt.figure(figsize=(8, 14))
[a,b,c,d]=data.shape
titles= ['U_x','U_y','U_z','p','k','omega', 'nut']

for i in range(d):
    fig.add_subplot(d, 2, i*2+1)
    plt.imshow(data[n,:,:,i],extent=[xlim[0],xlim[1],ylim[0],ylim[1]])
    plt.title('input ' +titles[i])
    plt.axis('off')
    plt.colorbar()
    
    fig.add_subplot(d, 2, i*2+2)
    plt.imshow(pred[n,:,:,i],extent=[xlim[0],xlim[1],ylim[0],ylim[1]])
    plt.title('pred '+titles[i])
    plt.axis('off')
    plt.colorbar()
    #print(i)

plt.show()

# %%
cfdnetplus.pred2OF2D(mainfolder,fields,xlim,ylim)
# Out:
# airFoil_500_0
# airFoil_500_20
# folder airfoil2d/airFoil_500/21 was created
# write airfoil2d/airFoil_500/21/U
# write airfoil2d/airFoil_500/21/p
# write airfoil2d/airFoil_500/21/k
# write airfoil2d/airFoil_500/21/omega
# write airfoil2d/airFoil_500/21/nut
